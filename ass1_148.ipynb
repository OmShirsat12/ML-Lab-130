# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Sample - Superstore.csv',encoding='unicode_escape')

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
(df.isnull().sum()/(len(df)))*100
# Out:
# Order ID         0.0
# Order Date       0.0
# Ship Date        0.0
# Ship Mode        0.0
# Customer ID      0.0
# Customer Name    0.0
# Segment          0.0
# Country          0.0
# State            0.0
# Postal Code      0.0
# Region           0.0
# Product ID       0.0
# Category         0.0
# Sub-Category     0.0
# Product Name     0.0
# Sales            0.0
# Quantity         0.0
# Discount         0.0
# Profit           0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   State          9994 non-null   object
#  9   Postal Code    9994 non-null   int64
#  10  Region         9994 non-null   object
#  11  Product ID     9994 non-null   object
#  12  Category       9994 non-null   object
#  13  Sub-Category   9994 non-null   object
#  14  Product Name   9994 non-null   object
#  15  Sales          9994 non-null   float64
#  16  Quantity       9994 non-null   int64
# ...

# %%
df = df.drop(['City'], axis=1)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   State          9994 non-null   object
#  9   Postal Code    9994 non-null   int64
#  10  Region         9994 non-null   object
#  11  Product ID     9994 non-null   object
#  12  Category       9994 non-null   object
#  13  Sub-Category   9994 non-null   object
#  14  Product Name   9994 non-null   object
#  15  Sales          9994 non-null   float64
#  16  Quantity       9994 non-null   int64
# ...

# %%
category_sales_profit = df.groupby('Category')[['Sales', 'Profit']].sum()
print("\nSales and Profit by Category:")
print(category_sales_profit)
# Out:
# Sales and Profit by Category:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481

# %%
df['Brand'] = df['Product Name'].str.split().str.get(0)
df['Model'] = df['Product Name'].str.split().str.slice(1, 3).str.join(" ")
df[['Product Name','Brand','Model']]
# Out:
#                                            Product Name          Brand  \
# 0                     Bush Somerset Collection Bookcase           Bush
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...            Hon
# 2     Self-Adhesive Address Labels for Typewriters b...  Self-Adhesive
# 3         Bretford CR4500 Series Slim Rectangular Table       Bretford
# 4                        Eldon Fold 'N Roll Cart System          Eldon
# ...                                                 ...            ...
# 9989                             Ultra Door Pull Handle          Ultra
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...          Tenex
# 9991                              Aastra 57i VoIP phone         Aastra
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"           It's
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...           Acco
#
#                      Model
# 0      Somerset Collection
# 1            Deluxe Fabric
# 2           Address Labels
# ...

# %%
print(df['Brand'].unique())  # Prints all unique brand names
print(df['Brand'].nunique())  # Prints the count of unique brand names
# Out:
# ['Bush' 'Hon' 'Self-Adhesive' 'Bretford' 'Eldon' 'Newell' 'Mitel' 'DXL'
#  'Belkin' 'Chromcraft' 'Konftel' 'Xerox' 'Fellowes' 'Holmes' 'Storex'
#  'Stur-D-Stor' 'Cisco' 'Wilson' 'Acco' 'Global' 'Imation' 'Riverside'
#  'Avery' 'Howard' 'Poly' 'BOSTON' 'Lumber' 'Easy-staple' 'GE' 'Electrix'
#  '#10-4' 'Atlantic' 'Plantronics' 'Panasonic' 'Advantus' 'Verbatim'
#  'Gould' 'LF' 'C-Line' 'Longer-Life' 'AT&T' 'Home/Office' 'Novimex'
#  'Array' 'Plastic' 'Prang' 'Luxo' 'Hunt' 'netTALK' 'Snap-A-Way'
#  'Telephone' 'High-Back' 'Tenex' 'Safco' 'Economy' '6"' 'SimpliFile' '1.7'
#  'Premium' 'Sortfiler' 'Jet-Pak' 'Logitech' 'Turquoise' 'Seth' 'Ibico'
#  'Flexible' '9-3/4' 'Trimflex' 'SanDisk' 'Universal' 'Deflect-o' 'Memorex'
#  'Speck' 'Magnifier' 'OIC' 'Redi-Strip' 'Tyvek' 'GBC' 'Artistic'
#  'Companion' 'Globe' 'KLD' 'Bevis' 'Trav-L-File' 'Anker' 'Staples'
#  'Sanford' 'Ideal' 'Fiskars' 'Convenience' 'Sanyo' 'Jabra' 'Southworth'
# ...

# %%
df.describe().T
# Out:
#               count          mean           std       min          25%  \
# Postal Code  9994.0  55190.379428  32063.693350  1040.000  23223.00000
# Sales        9994.0    229.858001    623.245101     0.444     17.28000
# Quantity     9994.0      3.789574      2.225110     1.000      2.00000
# Discount     9994.0      0.156203      0.206452     0.000      0.00000
# Profit       9994.0     28.656896    234.260108 -6599.978      1.72875
#
#                     50%        75%        max
# Postal Code  56430.5000  90008.000  99301.000
# Sales           54.4900    209.940  22638.480
# Quantity         3.0000      5.000     14.000
# Discount         0.2000      0.200      0.800
# Profit           8.6665     29.364   8399.976

# %%
df.describe(include='all').T
# Out:
#                 count unique              top  freq          mean  \
# Order ID         9994   5009   CA-2017-100111    14           NaN
# Order Date       9994   1237         9/5/2016    38           NaN
# Ship Date        9994   1334       12/16/2015    35           NaN
# Ship Mode        9994      4   Standard Class  5968           NaN
# Customer ID      9994    793         WB-21850    37           NaN
# Customer Name    9994    793    William Brown    37           NaN
# Segment          9994      3         Consumer  5191           NaN
# Country          9994      1    United States  9994           NaN
# State            9994     49       California  2001           NaN
# Postal Code    9994.0    NaN              NaN   NaN  55190.379428
# Region           9994      4             West  3203           NaN
# Product ID       9994   1862  OFF-PA-10001970    19           NaN
# Category         9994      3  Office Supplies  6026           NaN
# ...

# %%
import numpy as np

cat_cols = df.select_dtypes(include=['object']).columns
num_cols = df.select_dtypes(include=np.number).columns.tolist()

print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'State', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Brand', 'Model'],
#       dtype='object')
# Numerical Variables:
# ['Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in num_cols:
    print(col)
    print('Skew:', round(df[col].skew(), 2))
    
    plt.figure(figsize=(15, 4))
    
    # Histogram
    plt.subplot(1, 2, 1)
    df[col].hist(grid=False)
    plt.ylabel('count')
    plt.title(f'{col} Histogram')
    
    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col])
    plt.title(f'{col} Boxplot')
    
    plt.tight_layout()
    plt.show()
# Out:
# Postal Code
# Skew: -0.13
# Sales
# Skew: 12.97
# Quantity
# Skew: 1.28
# Discount
# Skew: 1.68
# Profit
# Skew: 7.56

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a 3x2 grid of subplots
fig, axes = plt.subplots(3, 2, figsize=(18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')

# Bar plots for categorical variables
sns.countplot(ax=axes[0, 0], x='Segment', data=df, color='blue', 
              order=df['Segment'].value_counts().index)
axes[0, 0].set_title('Segment Distribution')

sns.countplot(ax=axes[0, 1], x='Country', data=df, color='blue', 
              order=df['Country'].value_counts().index)
axes[0, 1].set_title('Country Distribution')

sns.countplot(ax=axes[1, 0], x='State', data=df, color='blue', 
              order=df['State'].value_counts().index)
axes[1, 0].set_title('State Distribution')

sns.countplot(ax=axes[1, 1], x='Region', data=df, color='blue', 
              order=df['Region'].value_counts().index)
axes[1, 1].set_title('Region Distribution')

sns.countplot(ax=axes[2, 0], x='Brand', data=df, color='blue', 
              order=df['Brand'].head(20).value_counts().index)
axes[2, 0].set_title('Brand Distribution (Top 20)')

sns.countplot(ax=axes[2, 1], x='Model', data=df, color='blue', 
              order=df['Model'].head(20).value_counts().index)
axes[2, 1].set_title('Model Distribution (Top 20)')

# Adjust tick label rotation for better visibility
axes[1, 1].tick_params(labelrotation=45)
axes[2, 0].tick_params(labelrotation=90)
axes[2, 1].tick_params(labelrotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %%
print(df.columns)
df.columns = df.columns.str.strip()
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'State', 'Postal Code', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit', 'Brand', 'Model'],
#       dtype='object')

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Function for log transformation of the column
def log_transform(df, col):
    for colname in col:
        # Handling zero or negative values before applying log transformation
        if (df[colname] <= 0).any():  # Checking if there are zero or negative values
            print(f"Warning: {colname} contains zero or negative values. Adding 1 to avoid log(0) or log(negative).")
            df[colname + '_log'] = np.log(df[colname] + 1)
        else:
            df[colname + '_log'] = np.log(df[colname])
    df.info()

# Apply log transformation on 'Sales', 'Quantity', 'Discount', and 'Profit'
log_transform(df, ['Sales', 'Quantity', 'Discount', 'Profit'])

# Log transformation of the feature 'Sales_log'
sns.histplot(df["Sales_log"], kde=True)
plt.xlabel("Sales_log")  # Corrected from axlabel to xlabel
plt.show()
# Out:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   State          9994 non-null   object
#  9   Postal Code    9994 non-null   int64
#  10  Region         9994 non-null   object
#  11  Product ID     9994 non-null   object
#  12  Category       9994 non-null   object
#  13  Sub-Category   9994 non-null   object
#  14  Product Name   9994 non-null   object
#  15  Sales          9994 non-null   float64
#  16  Quantity       9994 non-null   int64
# ...

# %%
# Drop rows with missing values
data_clean = df.dropna()

# Create pairplot for the cleaned data
plt.figure(figsize=(13, 17))
sns.pairplot(data_clean.drop(['Sales', 'Quantity'], axis=1))  # Dropping 'Sales' and 'Quantity' for visualization
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create subplots
fig, axarr = plt.subplots(4, 2, figsize=(12, 18))

# Plot Sales_log vs various categorical variables
df.groupby('Region')['Sales_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][0], fontsize=12)
axarr[0][0].set_title("Region Vs Sales", fontsize=18)

df.groupby('Ship Mode')['Sales_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][1], fontsize=12)
axarr[0][1].set_title("Ship Mode Vs Sales", fontsize=18)

df.groupby('Category')['Sales_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][0], fontsize=12)
axarr[1][0].set_title("Category Vs Sales", fontsize=18)

df.groupby('Sub-Category')['Sales_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][1], fontsize=12)
axarr[1][1].set_title("Sub-Category Vs Sales", fontsize=18)

df.groupby('Brand')['Sales_log'].mean().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][0], fontsize=12)
axarr[2][0].set_title("Brand Vs Sales", fontsize=18)

df.groupby('Model')['Sales_log'].mean().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][1], fontsize=12)
axarr[2][1].set_title("Model Vs Sales", fontsize=18)

# Assuming 'Postal Code' and 'Quantity' can be used as placeholders for Seats and Car_Age
df.groupby('Postal Code')['Sales_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[3][0], fontsize=12)
axarr[3][0].set_title("Postal Code Vs Sales", fontsize=18)

df.groupby('Quantity')['Sales_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[3][1], fontsize=12)
axarr[3][1].set_title("Quantity Vs Sales", fontsize=18)

# Adjust the layout and aesthetics
plt.subplots_adjust(hspace=1.0)
plt.subplots_adjust(wspace=0.5)
sns.despine()

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only the numerical columns from the data
numerical_data = df[['Sales', 'Quantity', 'Discount', 'Profit', 'Sales_log', 'Quantity_log', 'Discount_log', 'Profit_log']]

# Create a heatmap showing correlation between the numerical columns
plt.figure(figsize=(12, 7))
sns.heatmap(numerical_data.corr(), annot=True, vmin=-1, vmax=1)

# Show the plot
plt.show()

# %%
# Checking for missing values in the columns
print(df[['Sales', 'Quantity', 'Discount', 'Profit', 'Sales_log', 'Quantity_log']].isnull().sum())

# Fill missing values for 'Sales', 'Quantity', 'Discount', 'Profit', 'Sales_log', 'Quantity_log' with the median of the respective 'Model' and 'Brand' grouping
df['Sales'].fillna(value=np.nan, inplace=True)
df['Sales'] = df.groupby(['Model', 'Brand'], group_keys=False)['Sales'].apply(lambda x: x.fillna(x.median()))

df['Quantity'].fillna(value=np.nan, inplace=True)
df['Quantity'] = df.groupby(['Model', 'Brand'], group_keys=False)['Quantity'].apply(lambda x: x.fillna(x.median()))

df['Discount'].fillna(value=np.nan, inplace=True)
df['Discount'] = df.groupby(['Model', 'Brand'], group_keys=False)['Discount'].apply(lambda x: x.fillna(x.median()))

df['Profit'].fillna(value=np.nan, inplace=True)
df['Profit'] = df.groupby(['Model', 'Brand'], group_keys=False)['Profit'].apply(lambda x: x.fillna(x.median()))

df['Sales_log'].fillna(value=np.nan, inplace=True)
df['Sales_log'] = df.groupby(['Model', 'Brand'], group_keys=False)['Sales_log'].apply(lambda x: x.fillna(x.median()))

df['Quantity_log'].fillna(value=np.nan, inplace=True)
df['Quantity_log'] = df.groupby(['Model', 'Brand'], group_keys=False)['Quantity_log'].apply(lambda x: x.fillna(x.median()))
# Out:
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# Sales_log       0
# Quantity_log    0
# dtype: int64
